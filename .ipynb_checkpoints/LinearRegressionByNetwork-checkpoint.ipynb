# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def load_data():
    # 从文件导入数据
    datafile = 'housing.data'
    data = np.fromfile(datafile, sep=' ')

    # 每条数据包括14项，其中前面13项是影响因素，第14项是相应的房屋价格中位数
    feature_names = [ 'CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', \
                      'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV' ]
    feature_num = len(feature_names)

    # 将原始数据进行Reshape，变成[N, 14]这样的形状
    data = data.reshape([data.shape[0] // feature_num, feature_num])

    # 将原数据集拆分成训练集和测试集
    # 这里使用80%的数据做训练，20%的数据做测试
    # 测试集和训练集必须是没有交集的
    ratio = 0.8
    offset = int(data.shape[0] * ratio)
    training_data = data[:offset]

    # 计算train数据集的最大值，最小值，平均值
    maximums, minimums, means, stds = \
    training_data.max(axis=0), \
    training_data.min(axis=0), \
    training_data.mean(axis=0),\
    training_data.std(axis=0)
    
    # 对数据进行归一化处理
    for i in range(feature_num):
        data[:,i]=(data[:,i]-means[i])/stds[i]
        
     # 训练集和测试集的划分比例
    training_data = data[:offset]
    test_data = data[offset:]
    return training_data, test_data

# %%
class Network(object):
    def __init__(self, num_of_weights):
        # 随机产生w的初始值
        # 为了保持程序每次运行结果的一致性，
        # 此处设置固定的随机数种子
        np.random.seed(0)
        self.w = np.random.randn(num_of_weights, 1)
        self.b = 0.

    # 定义前向计算成员函数
    def forward(self, x):
        z = x.dot(self.w)+self.b
        return z

    # 定义计算损失函数值的成员函数
    def loss(self, z, y):
        error = z-y
        cost = error*error
        cost = np.mean(cost)
        return cost

    # 定义计算梯度的成员函数
    def gradient(self, x, y):
        z = self.forward(x)
        gradient_w = (z-y)*x
        gradient_w = np.mean(gradient_w, axis=0)
        gradient_w = gradient_w[:, np.newaxis]
        gradient_b = (z - y)
        gradient_b = np.mean(gradient_b)

        return gradient_w, gradient_b

    def updata(self, gradient_w, gradient_b, eta=0.01):
        self.w -= eta*gradient_w
        self.b -= eta*gradient_b

    def train(self, training_data, num_epoches, batch_size=10, eta=0.01):
        n = len(training_data)
        losses = []
        for epoch_id in range(num_epoches):
            # 在每轮迭代开始之前，将训练数据的顺序随机的打乱，
            # 然后再按每次取batch_size条数据的方式取出
            np.random.shuffle(training_data)
            # 将训练数据进行拆分，每个mini_batch包含batch_size条的数据
            mini_batches = [training_data[k: k+batch_size]
                            for k in range(0, n, batch_size)]
            for iter_id, mini_batch in enumerate(mini_batches):
                x = mini_batch[:, :-1]
                y = mini_batch[:, -1:]
                z = self.forward(x)
                loss = self.loss(z, y)
                gradient_w, gradient_b = self.gradient(x, y)
                self.updata(gradient_w, gradient_b, eta)
                losses.append(loss)
                print(
                    'Epoch {:3d} / iter {:3d}, loss {:.4f}'.format(epoch_id, iter_id, loss))
        return losses

# %%
# 获取数据
train_data, test_data = load_data()
# 创建网络
net = Network(13)
# 启动训练
losses = net.train(train_data, num_epoches=50, batch_size=100, eta=0.1)

# 画出损失函数的变化趋势
plot_x = np.arange(len(losses))
plot_y = np.array(losses)
plt.plot(plot_x, plot_y)
plt.show()
# Out:
# Epoch   0 / iter   0, loss 47.8387
# Epoch   0 / iter   1, loss 8.5208
# Epoch   0 / iter   2, loss 8.0082
# Epoch   0 / iter   3, loss 7.9864
# Epoch   0 / iter   4, loss 1.8815
# Epoch   1 / iter   0, loss 4.2831
# Epoch   1 / iter   1, loss 2.8137
# Epoch   1 / iter   2, loss 4.1185
# Epoch   1 / iter   3, loss 4.6027
# Epoch   1 / iter   4, loss 0.8393
# Epoch   2 / iter   0, loss 2.3999
# Epoch   2 / iter   1, loss 1.6230
# Epoch   2 / iter   2, loss 2.3380
# Epoch   2 / iter   3, loss 2.8625
# Epoch   2 / iter   4, loss 0.3122
# Epoch   3 / iter   0, loss 1.6103
# Epoch   3 / iter   1, loss 2.0899
# Epoch   3 / iter   2, loss 1.2466
# Epoch   3 / iter   3, loss 1.2898
# Epoch   3 / iter   4, loss 0.3289
# Epoch   4 / iter   0, loss 1.1270
# Epoch   4 / iter   1, loss 1.0388
# Epoch   4 / iter   2, loss 1.2513
# Epoch   4 / iter   3, loss 1.0923
# Epoch   4 / iter   4, loss 0.3748
# Epoch   5 / iter   0, loss 1.1727
# Epoch   5 / iter   1, loss 1.0228
# Epoch   5 / iter   2, loss 0.6489
# Epoch   5 / iter   3, loss 0.5894
# Epoch   5 / iter   4, loss 0.7507
# Epoch   6 / iter   0, loss 0.7477
# Epoch   6 / iter   1, loss 0.5101
# Epoch   6 / iter   2, loss 0.5369
# Epoch   6 / iter   3, loss 0.9179
# Epoch   6 / iter   4, loss 0.3192
# Epoch   7 / iter   0, loss 0.6413
# Epoch   7 / iter   1, loss 0.3064
# Epoch   7 / iter   2, loss 0.6712
# Epoch   7 / iter   3, loss 0.6573
# Epoch   7 / iter   4, loss 0.3001
# Epoch   8 / iter   0, loss 0.3643
# Epoch   8 / iter   1, loss 0.5384
# Epoch   8 / iter   2, loss 0.7840
# Epoch   8 / iter   3, loss 0.4359
# Epoch   8 / iter   4, loss 0.0988
# Epoch   9 / iter   0, loss 0.5724
# Epoch   9 / iter   1, loss 0.4343
# Epoch   9 / iter   2, loss 0.2787
# Epoch   9 / iter   3, loss 0.5969
# Epoch   9 / iter   4, loss 0.5384
# Epoch  10 / iter   0, loss 0.5716
# Epoch  10 / iter   1, loss 0.2486
# Epoch  10 / iter   2, loss 0.5131
# Epoch  10 / iter   3, loss 0.3939
# Epoch  10 / iter   4, loss 0.5211
# Epoch  11 / iter   0, loss 0.5795
# Epoch  11 / iter   1, loss 0.6360
# Epoch  11 / iter   2, loss 0.3283
# Epoch  11 / iter   3, loss 0.2922
# Epoch  11 / iter   4, loss 0.4017
# Epoch  12 / iter   0, loss 0.3908
# Epoch  12 / iter   1, loss 0.5280
# Epoch  12 / iter   2, loss 0.2809
# Epoch  12 / iter   3, loss 0.5673
# Epoch  12 / iter   4, loss 0.0230
# Epoch  13 / iter   0, loss 0.5060
# Epoch  13 / iter   1, loss 0.3012
# Epoch  13 / iter   2, loss 0.2632
# Epoch  13 / iter   3, loss 0.4344
# Epoch  13 / iter   4, loss 0.0582
# Epoch  14 / iter   0, loss 0.3204
# Epoch  14 / iter   1, loss 0.3828
# Epoch  14 / iter   2, loss 0.4294
# Epoch  14 / iter   3, loss 0.3129
# Epoch  14 / iter   4, loss 0.1179
# Epoch  15 / iter   0, loss 0.2252
# Epoch  15 / iter   1, loss 0.3751
# Epoch  15 / iter   2, loss 0.3851
# Epoch  15 / iter   3, loss 0.3435
# Epoch  15 / iter   4, loss 1.1461
# Epoch  16 / iter   0, loss 0.4043
# Epoch  16 / iter   1, loss 0.2307
# Epoch  16 / iter   2, loss 0.3539
# Epoch  16 / iter   3, loss 0.4416
# Epoch  16 / iter   4, loss 0.3738
# Epoch  17 / iter   0, loss 0.4913
# Epoch  17 / iter   1, loss 0.3442
# Epoch  17 / iter   2, loss 0.3146
# Epoch  17 / iter   3, loss 0.2892
# Epoch  17 / iter   4, loss 0.0524
# Epoch  18 / iter   0, loss 0.3218
# Epoch  18 / iter   1, loss 0.2767
# Epoch  18 / iter   2, loss 0.2542
# Epoch  18 / iter   3, loss 0.4065
# Epoch  18 / iter   4, loss 0.1483
# Epoch  19 / iter   0, loss 0.2601
# Epoch  19 / iter   1, loss 0.3786
# Epoch  19 / iter   2, loss 0.2845
# Epoch  19 / iter   3, loss 0.3142
# Epoch  19 / iter   4, loss 0.1019
# Epoch  20 / iter   0, loss 0.3017
# Epoch  20 / iter   1, loss 0.2316
# Epoch  20 / iter   2, loss 0.3632
# Epoch  20 / iter   3, loss 0.3229
# Epoch  20 / iter   4, loss 0.2811
# Epoch  21 / iter   0, loss 0.5841
# Epoch  21 / iter   1, loss 0.1998
# Epoch  21 / iter   2, loss 0.3627
# Epoch  21 / iter   3, loss 0.2207
# Epoch  21 / iter   4, loss 0.2183
# Epoch  22 / iter   0, loss 0.3775
# Epoch  22 / iter   1, loss 0.3249
# Epoch  22 / iter   2, loss 0.3060
# Epoch  22 / iter   3, loss 0.2103
# Epoch  22 / iter   4, loss 0.0349
# Epoch  23 / iter   0, loss 0.2567
# Epoch  23 / iter   1, loss 0.2863
# Epoch  23 / iter   2, loss 0.2514
# Epoch  23 / iter   3, loss 0.3558
# Epoch  23 / iter   4, loss 0.9522
# Epoch  24 / iter   0, loss 0.4005
# Epoch  24 / iter   1, loss 0.3681
# Epoch  24 / iter   2, loss 0.3241
# Epoch  24 / iter   3, loss 0.3579
# Epoch  24 / iter   4, loss 0.3450
# Epoch  25 / iter   0, loss 0.2372
# Epoch  25 / iter   1, loss 0.5746
# Epoch  25 / iter   2, loss 0.1703
# Epoch  25 / iter   3, loss 0.2294
# Epoch  25 / iter   4, loss 0.5440
# Epoch  26 / iter   0, loss 0.3365
# Epoch  26 / iter   1, loss 0.3253
# Epoch  26 / iter   2, loss 0.2703
# Epoch  26 / iter   3, loss 0.2986
# Epoch  26 / iter   4, loss 0.0801
# Epoch  27 / iter   0, loss 0.3054
# Epoch  27 / iter   1, loss 0.2219
# Epoch  27 / iter   2, loss 0.2989
# Epoch  27 / iter   3, loss 0.3345
# Epoch  27 / iter   4, loss 0.2335
# Epoch  28 / iter   0, loss 0.2482
# Epoch  28 / iter   1, loss 0.2002
# Epoch  28 / iter   2, loss 0.3932
# Epoch  28 / iter   3, loss 0.3229
# Epoch  28 / iter   4, loss 0.0754
# Epoch  29 / iter   0, loss 0.1777
# Epoch  29 / iter   1, loss 0.2585
# Epoch  29 / iter   2, loss 0.3798
# Epoch  29 / iter   3, loss 0.3200
# Epoch  29 / iter   4, loss 0.2642
# Epoch  30 / iter   0, loss 0.3293
# Epoch  30 / iter   1, loss 0.3281
# Epoch  30 / iter   2, loss 0.2347
# Epoch  30 / iter   3, loss 0.2837
# Epoch  30 / iter   4, loss 0.1442
# Epoch  31 / iter   0, loss 0.1866
# Epoch  31 / iter   1, loss 0.4091
# Epoch  31 / iter   2, loss 0.2121
# Epoch  31 / iter   3, loss 0.3432
# Epoch  31 / iter   4, loss 0.2009
# Epoch  32 / iter   0, loss 0.1977
# Epoch  32 / iter   1, loss 0.3895
# Epoch  32 / iter   2, loss 0.2957
# Epoch  32 / iter   3, loss 0.2779
# Epoch  32 / iter   4, loss 0.4541
# Epoch  33 / iter   0, loss 0.3818
# Epoch  33 / iter   1, loss 0.2510
# Epoch  33 / iter   2, loss 0.4202
# Epoch  33 / iter   3, loss 0.2548
# Epoch  33 / iter   4, loss 0.1622
# Epoch  34 / iter   0, loss 0.3333
# Epoch  34 / iter   1, loss 0.3706
# Epoch  34 / iter   2, loss 0.1476
# Epoch  34 / iter   3, loss 0.3054
# Epoch  34 / iter   4, loss 0.0821
# Epoch  35 / iter   0, loss 0.3730
# Epoch  35 / iter   1, loss 0.3020
# Epoch  35 / iter   2, loss 0.3107
# Epoch  35 / iter   3, loss 0.1885
# Epoch  35 / iter   4, loss 0.0791
# Epoch  36 / iter   0, loss 0.2410
# Epoch  36 / iter   1, loss 0.2387
# Epoch  36 / iter   2, loss 0.3780
# Epoch  36 / iter   3, loss 0.2964
# Epoch  36 / iter   4, loss 0.0268
# Epoch  37 / iter   0, loss 0.2052
# Epoch  37 / iter   1, loss 0.2763
# Epoch  37 / iter   2, loss 0.3808
# Epoch  37 / iter   3, loss 0.2103
# Epoch  37 / iter   4, loss 2.0696
# Epoch  38 / iter   0, loss 0.4797
# Epoch  38 / iter   1, loss 0.4179
# Epoch  38 / iter   2, loss 0.3553
# Epoch  38 / iter   3, loss 0.2399
# Epoch  38 / iter   4, loss 0.1502
# Epoch  39 / iter   0, loss 0.2926
# Epoch  39 / iter   1, loss 0.3243
# Epoch  39 / iter   2, loss 0.3336
# Epoch  39 / iter   3, loss 0.2162
# Epoch  39 / iter   4, loss 0.1299
# Epoch  40 / iter   0, loss 0.2462
# Epoch  40 / iter   1, loss 0.3385
# Epoch  40 / iter   2, loss 0.1964
# Epoch  40 / iter   3, loss 0.3585
# Epoch  40 / iter   4, loss 0.1037
# Epoch  41 / iter   0, loss 0.2992
# Epoch  41 / iter   1, loss 0.2683
# Epoch  41 / iter   2, loss 0.2655
# Epoch  41 / iter   3, loss 0.2803
# Epoch  41 / iter   4, loss 0.1133
# Epoch  42 / iter   0, loss 0.3883
# Epoch  42 / iter   1, loss 0.2153
# Epoch  42 / iter   2, loss 0.1989
# Epoch  42 / iter   3, loss 0.3293
# Epoch  42 / iter   4, loss 0.0744
# Epoch  43 / iter   0, loss 0.2446
# Epoch  43 / iter   1, loss 0.2516
# Epoch  43 / iter   2, loss 0.3566
# Epoch  43 / iter   3, loss 0.2492
# Epoch  43 / iter   4, loss 0.1924
# Epoch  44 / iter   0, loss 0.2718
# Epoch  44 / iter   1, loss 0.3513
# Epoch  44 / iter   2, loss 0.2265
# Epoch  44 / iter   3, loss 0.2801
# Epoch  44 / iter   4, loss 0.0348
# Epoch  45 / iter   0, loss 0.3207
# Epoch  45 / iter   1, loss 0.2073
# Epoch  45 / iter   2, loss 0.2034
# Epoch  45 / iter   3, loss 0.3692
# Epoch  45 / iter   4, loss 0.1385
# Epoch  46 / iter   0, loss 0.2805
# Epoch  46 / iter   1, loss 0.3595
# Epoch  46 / iter   2, loss 0.2300
# Epoch  46 / iter   3, loss 0.2449
# Epoch  46 / iter   4, loss 0.2376
# Epoch  47 / iter   0, loss 0.3298
# Epoch  47 / iter   1, loss 0.2820
# Epoch  47 / iter   2, loss 0.2461
# Epoch  47 / iter   3, loss 0.2558
# Epoch  47 / iter   4, loss 0.2759
# Epoch  48 / iter   0, loss 0.3890
# Epoch  48 / iter   1, loss 0.3202
# Epoch  48 / iter   2, loss 0.3542
# Epoch  48 / iter   3, loss 0.1819
# Epoch  48 / iter   4, loss 0.0675
# Epoch  49 / iter   0, loss 0.2243
# Epoch  49 / iter   1, loss 0.2829
# Epoch  49 / iter   2, loss 0.3352
# Epoch  49 / iter   3, loss 0.3149
# Epoch  49 / iter   4, loss 0.1550

# %%
from mpl_toolkits.mplot3d import Axes3D

# 只画出参数w5和w9在区间[-160, 160]的曲线部分，已经包含损失函数的极值
w5 = np.arange(-160.0, 160.0, 1.0)
w9 = np.arange(-160.0, 160.0, 1.0)
losses = np.zeros([len(w5), len(w9)])
x=train_data[:,:-1]
y=train_data[:,-1:]

# 计算设定区域内每个参数取值所对应的Loss
for i in range(len(w5)):
    for j in range(len(w9)):
        net.w[5] = w5[i]
        net.w[9] = w9[j]
        z = net.forward(x)
        loss = net.loss(z, y)
        losses[i, j] = loss

# 将两个变量和对应的Loss作3D图
fig = plt.figure()
ax = Axes3D(fig)

w5, w9 = np.meshgrid(w5, w9)

ax.plot_surface(w5, w9, losses, rstride=1, cstride=1, cmap='rainbow')
plt.show()
